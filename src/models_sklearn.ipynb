# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
data = pd.read_pickle("../data_preprocessed/data.pkl")

# %%
data['date'] = pd.to_numeric(pd.to_datetime(data['date']))
# TODO separate days, months as features (more expensive in some months??)

cols_cat = [
 'district',
 'parking']

for c in cols_cat:
    if c in data:
        data[c] = pd.Categorical(data[c])

data.head(3)
# Out:
#     price_id  flat_id   price                 date  flat_id  \
# 4          5        4  390000  1610928000000000000        4
# 11        12       11  500000  1611705600000000000       11
# 12        13       12  590000  1611878400000000000       12
#
#                         ad_id  \
# 4   1004683230600910484697409
# 11  1005929025950911462330809
# 12  1005939166310911450918709
#
#                                                 title date_posted  \
# 4      Nowa kawalerka do wprowadzenia w chmurach 15p   2019-04-04
# 11  Za gotówkę ! Praga Południe gratka dla inwesto...  2019-09-22
# 12  50m, Praga Południe (będzie Metro), 2 pokoje d...  2019-09-23
#
#    date_scraped                  location  ... num_bathrooms flat_area   text  \
# 4    2021-01-18  Praga Południe, Warszawa  ...             1        26  Garaż
# 11   2021-01-27  Praga Południe, Warszawa  ...             1        43   Brak
# 12   2021-01-29  Praga Południe, Warszawa  ...             1        50   Brak
#
#                                           description  \
# 4   AGENCJE NIERUCHOMOSCI PROSZĘ NIE DZWONIĆ! BEZP...
# 11  Mieszkanie dobrze rozplanowane 2 pokoje z osob...
# 12  Zakup tylko za gotówkę - grunt podlega regulac...
#
#                                          photos_links  \
# 4   ['https://i.ebayimg.com/00/s/NjAwWDgwMA==/z/m4...
# 11  ['https://i.ebayimg.com/00/s/ODAwWDU5NA==/z/hn...
# 12  ['https://i.ebayimg.com/00/s/ODAwWDYwMA==/z/Sn...
#
#                                          page_address   district  \
# 4   https://www.gumtree.pl/a-mieszkania-i-domy-spr...  praga_pld
# 11  https://www.gumtree.pl/a-mieszkania-i-domy-spr...  praga_pld
# 12  https://www.gumtree.pl/a-mieszkania-i-domy-spr...  praga_pld
#
#    private_owner parking price_per_m
# 4              1  garage       15000
# 11             1    none       11627
# 12             1    none       11800
#
# [3 rows x 23 columns]

# %%
num_selector = make_column_selector(dtype_include='number')
cat_selector = make_column_selector(dtype_include='category')

# cat_transformer = OrdinalEncoder()
cat_transformer = OneHotEncoder()
# Word to vec model - embedding for each description - LSTM --> encoding for the entire sentence, embedding for the whole desc as a new feature
# Pick features: 

scaler = StandardScaler()  # I can use a different one (max scaling ... )
transformer = make_column_transformer(
    (scaler, num_selector),
    (cat_transformer, cat_selector),
)

# %%
cols = [
#  'date',
 'num_rooms',
 'num_bathrooms',
 'flat_area',
 'district',
 'private_owner',
 'parking']

# %%
y = data['price'].copy()
X = data[cols].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)
# make sure it's stratified

X_train_raw = X_train.copy()
X_test_raw = X_test.copy()

print(X_train.shape)
# Out:
# (319622, 6)

# %%
X_train = transformer.fit_transform(X_train)
X_test = transformer.transform(X_test)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (319622, 26)
# (319622,)
# (136982, 26)

# %%
X_train_baseline = transformer.fit_transform(X_train_raw[['flat_area', 'district']])
X_test_baseline = transformer.transform(X_test_raw[['flat_area', 'district']])

# %% [markdown]
# # Regression

# %%
regr = LinearRegression()

regr.fit(X_train_baseline, y_train)
y_pred_regr = regr.predict(X_test_baseline)

print(f"Score: {regr.score(X_test_baseline, y_test)}")
print(f"Regression: {mean_absolute_error(y_test, y_pred_regr)}")
# Out:
# Score: 0.7147678768034906
# Regression: 136435.62996296302

# %% [markdown]
# # Decision Tree

# %%
regr_tree = DecisionTreeRegressor()

regr_tree.fit(X_train, y_train)
y_pred_tree = regr_tree.predict(X_test)

print(f"Score: {regr_tree.score(X_test, y_test)}")
print(f"Tree: {mean_absolute_error(y_test, y_pred_tree)}")
# Out:
# Score: 0.9048254098903495
# Tree: 72924.98491280308

# %% [markdown]
# # RandomForestRegressor

# %%
regr_forest = RandomForestRegressor()
regr_forest.fit(X_train, y_train)

y_pred_forest = regr_forest.predict(X_test)

print(f"Score: {regr_forest.score(X_test, y_test)}")
print(f"Forest: {mean_absolute_error(y_test, y_pred_forest)}")
# Out:
# Score: 0.9062131100813566
# Forest: 73037.12937273565

# %% [markdown]
# # SVM

# %%
# svm = SVR()
# svm.fit(X_train, y_train)

# y_pred_svm = svm.predict(X_test)

# svm.score(X_test, y_test)

# %%
# mean_absolute_error(y_test, y_pred_svm)

# %% [markdown]
# # KNN

# %%
# knn = KNeighborsRegressor()
# knn.fit(X_train, y_train)

# y_pred_knn = knn.predict(X_test)

# print(f"Score: {knn.score(X_test, y_test)}")
# print(f"KNN: {mean_absolute_error(y_test, y_pred_knn)}")

# %% [markdown]
# # Comparison

# %%
print(f"Regression: {mean_absolute_error(y_test, y_pred_regr)}")
print(f"Tree: {mean_absolute_error(y_test, y_pred_tree)}")
print(f"Forest: {mean_absolute_error(y_test, y_pred_forest)}")
# print(f"KNN: {mean_absolute_error(y_test, y_pred_knn)}")
# Out:
# Regression: 136435.62996296302
# Tree: 72924.98491280308
# Forest: 73037.12937273565

# %%
X_test_raw['y_true'] = y_test
X_test_raw['y_pred_regr'] = y_pred_regr
X_test_raw['y_pred_tree'] = y_pred_tree
X_test_raw['y_pred_forest'] = y_pred_forest
# X_test_raw['y_pred_knn'] = y_pred_knn

# X_test_raw['diff'] = abs(X_test_raw['y_true'] - X_test_raw['y_pred'])
X_test_raw['diff_prc_regr'] = abs(X_test_raw['y_true'] - X_test_raw['y_pred_regr'])/X_test_raw['y_true']*100
X_test_raw['diff_prc_tree'] = abs(X_test_raw['y_true'] - X_test_raw['y_pred_tree'])/X_test_raw['y_true']*100
X_test_raw['diff_prc_forest'] = abs(X_test_raw['y_true'] - X_test_raw['y_pred_forest'])/X_test_raw['y_true']*100
# X_test_raw['diff_prc_knn'] = abs(X_test_raw['y_true'] - X_test_raw['y_pred_knn'])/X_test_raw['y_true']*100

pd.set_option('display.float_format', lambda x: '%.3f' % x)

X_test_raw_sorted = X_test_raw.sort_values(by=['diff_prc_tree'], ascending=False)

X_test_raw_sorted.head()
# Out:
#         num_rooms  num_bathrooms  flat_area     district  private_owner  \
# 369006          3              1         53      ursynow              0
# 381943          2              1         40  srodmiescie              1
# 381951          2              1         40  srodmiescie              1
# 363222          2              1         42       bemowo              0
# 432724          3              1         60      mokotow              0
#
#        parking  y_true  y_pred_regr  y_pred_tree  y_pred_forest  \
# 369006    none   55000   584502.462   575773.506     575692.159
# 381943  street   57500   684121.420   597205.128     597178.660
# 381951  street   57500   684121.420   597205.128     597178.660
# 363222    none   47500   426214.644   471379.066     471807.616
# 432724    none   72000   823768.131   710439.910     710136.307
#
#         diff_prc_regr  diff_prc_tree  diff_prc_forest
# 369006        962.732        946.861          946.713
# 381943       1089.776        938.618          938.572
# 381951       1089.776        938.618          938.572
# 363222        797.294        892.377          893.279
# 432724       1044.122        886.722          886.300

# %%
list(X_test_raw_sorted)
# Out:
# ['num_rooms',
#  'num_bathrooms',
#  'flat_area',
#  'district',
#  'private_owner',
#  'parking',
#  'y_true',
#  'y_pred_regr',
#  'y_pred_tree',
#  'y_pred_forest',
#  'diff_prc_regr',
#  'diff_prc_tree',
#  'diff_prc_forest']

# %%
districts = X_test_raw['district'].unique()

for district in districts:
    df_dist = X_test_raw.loc[X_test_raw['district'] == district]

    q_25 = df_dist['y_true'].quantile(0.25) 
    q_50 = df_dist['y_true'].quantile(0.5) 
    q_75 = df_dist['y_true'].quantile(0.75) 
    max_price = max(df_dist['y_true'])

    for q in [q_25, q_50, q_75, max_price]:
        df_dist_price = df_dist.loc[df_dist['y_true'] < q]
        df_dist_price = df_dist_price[['diff_prc_regr', 'diff_prc_tree','diff_prc_forest']]

        stats_unformatted = dict(df_dist_price.mean(axis=0))
        stats = {k: int(v) for k, v in stats_unformatted.items()}

        print(f"{district}, max price: {q}, flats: {len(df_dist_price)}")
        print(stats)
        print("_"*60)
# Out:
# ochota, max price: 470000.0, flats: 2124
# {'diff_prc_regr': 13, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# ochota, max price: 630000.0, flats: 4196
# {'diff_prc_regr': 11, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# ochota, max price: 900000.0, flats: 6379
# {'diff_prc_regr': 11, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# ochota, max price: 2190000, flats: 8509
# {'diff_prc_regr': 11, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# ursynow, max price: 550000.0, flats: 2034
# {'diff_prc_regr': 15, 'diff_prc_tree': 10, 'diff_prc_forest': 10}
# ____________________________________________________________
# ursynow, max price: 686000.0, flats: 4170
# {'diff_prc_regr': 14, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# ursynow, max price: 890000.0, flats: 6281
# {'diff_prc_regr': 13, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# ursynow, max price: 1858000, flats: 8397
# {'diff_prc_regr': 15, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# wola, max price: 475000.0, flats: 6676
# {'diff_prc_regr': 14, 'diff_prc_tree': 13, 'diff_prc_forest': 13}
# ____________________________________________________________
# wola, max price: 600000.0, flats: 13501
# {'diff_prc_regr': 13, 'diff_prc_tree': 12, 'diff_prc_forest': 12}
# ____________________________________________________________
# wola, max price: 759000.0, flats: 20232
# {'diff_prc_regr': 14, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# wola, max price: 2200000, flats: 27027
# {'diff_prc_regr': 15, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# praga_pln, max price: 454528.0, flats: 1403
# {'diff_prc_regr': 17, 'diff_prc_tree': 10, 'diff_prc_forest': 10}
# ____________________________________________________________
# praga_pln, max price: 550000.0, flats: 2752
# {'diff_prc_regr': 17, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# praga_pln, max price: 735250.0, flats: 4212
# {'diff_prc_regr': 17, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# praga_pln, max price: 1600000, flats: 5577
# {'diff_prc_regr': 16, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# bemowo, max price: 529000.0, flats: 2415
# {'diff_prc_regr': 16, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# bemowo, max price: 615000.0, flats: 4896
# {'diff_prc_regr': 16, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# bemowo, max price: 749000.0, flats: 7375
# {'diff_prc_regr': 16, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# bemowo, max price: 2500000, flats: 9842
# {'diff_prc_regr': 15, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# praga_pld, max price: 480000.0, flats: 3638
# {'diff_prc_regr': 20, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# praga_pld, max price: 588000.0, flats: 7354
# {'diff_prc_regr': 18, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# praga_pld, max price: 729000.0, flats: 11022
# {'diff_prc_regr': 17, 'diff_prc_tree': 10, 'diff_prc_forest': 10}
# ____________________________________________________________
# praga_pld, max price: 1625000, flats: 14727
# {'diff_prc_regr': 18, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# mokotow, max price: 538362.0, flats: 5454
# {'diff_prc_regr': 20, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# mokotow, max price: 699000.0, flats: 10912
# {'diff_prc_regr': 19, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# mokotow, max price: 1000000.0, flats: 16366
# {'diff_prc_regr': 17, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# mokotow, max price: 7870000, flats: 21911
# {'diff_prc_regr': 17, 'diff_prc_tree': 10, 'diff_prc_forest': 10}
# ____________________________________________________________
# srodmiescie, max price: 559000.0, flats: 6352
# {'diff_prc_regr': 40, 'diff_prc_tree': 17, 'diff_prc_forest': 17}
# ____________________________________________________________
# srodmiescie, max price: 750000.0, flats: 12831
# {'diff_prc_regr': 29, 'diff_prc_tree': 15, 'diff_prc_forest': 15}
# ____________________________________________________________
# srodmiescie, max price: 1050000.0, flats: 19324
# {'diff_prc_regr': 25, 'diff_prc_tree': 14, 'diff_prc_forest': 14}
# ____________________________________________________________
# srodmiescie, max price: 3545098, flats: 25770
# {'diff_prc_regr': 24, 'diff_prc_tree': 13, 'diff_prc_forest': 13}
# ____________________________________________________________
# wilanow, max price: 660000.0, flats: 882
# {'diff_prc_regr': 17, 'diff_prc_tree': 9, 'diff_prc_forest': 10}
# ____________________________________________________________
# wilanow, max price: 800000.0, flats: 1763
# {'diff_prc_regr': 14, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# wilanow, max price: 1098125.0, flats: 2641
# {'diff_prc_regr': 13, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# wilanow, max price: 2550000, flats: 3518
# {'diff_prc_regr': 14, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# targowek, max price: 432000.0, flats: 1371
# {'diff_prc_regr': 17, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# targowek, max price: 489000.0, flats: 2759
# {'diff_prc_regr': 14, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# targowek, max price: 599000.0, flats: 4156
# {'diff_prc_regr': 13, 'diff_prc_tree': 6, 'diff_prc_forest': 6}
# ____________________________________________________________
# targowek, max price: 1155000, flats: 5565
# {'diff_prc_regr': 14, 'diff_prc_tree': 6, 'diff_prc_forest': 7}
# ____________________________________________________________
# bialoleka, max price: 393000.0, flats: 230
# {'diff_prc_regr': 15, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# bialoleka, max price: 420000.0, flats: 546
# {'diff_prc_regr': 12, 'diff_prc_tree': 6, 'diff_prc_forest': 6}
# ____________________________________________________________
# bialoleka, max price: 470000.0, flats: 812
# {'diff_prc_regr': 13, 'diff_prc_tree': 5, 'diff_prc_forest': 5}
# ____________________________________________________________
# bialoleka, max price: 849800, flats: 1100
# {'diff_prc_regr': 13, 'diff_prc_tree': 5, 'diff_prc_forest': 5}
# ____________________________________________________________
# zoliboz, max price: 550000.0, flats: 988
# {'diff_prc_regr': 18, 'diff_prc_tree': 10, 'diff_prc_forest': 10}
# ____________________________________________________________
# zoliboz, max price: 695000.0, flats: 2067
# {'diff_prc_regr': 16, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# zoliboz, max price: 900000.0, flats: 3085
# {'diff_prc_regr': 14, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# zoliboz, max price: 2460000, flats: 4135
# {'diff_prc_regr': 15, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# wesola, max price: 407220.0, flats: 8
# {'diff_prc_regr': 29, 'diff_prc_tree': 27, 'diff_prc_forest': 29}
# ____________________________________________________________
# wesola, max price: 496944.0, flats: 16
# {'diff_prc_regr': 25, 'diff_prc_tree': 21, 'diff_prc_forest': 20}
# ____________________________________________________________
# wesola, max price: 590410.0, flats: 24
# {'diff_prc_regr': 31, 'diff_prc_tree': 21, 'diff_prc_forest': 22}
# ____________________________________________________________
# wesola, max price: 940000, flats: 32
# {'diff_prc_regr': 30, 'diff_prc_tree': 25, 'diff_prc_forest': 23}
# ____________________________________________________________
# wawer, max price: 339000.0, flats: 42
# {'diff_prc_regr': 6, 'diff_prc_tree': 6, 'diff_prc_forest': 5}
# ____________________________________________________________
# wawer, max price: 339000.0, flats: 42
# {'diff_prc_regr': 6, 'diff_prc_tree': 6, 'diff_prc_forest': 5}
# ____________________________________________________________
# wawer, max price: 459000.0, flats: 173
# {'diff_prc_regr': 6, 'diff_prc_tree': 2, 'diff_prc_forest': 2}
# ____________________________________________________________
# wawer, max price: 650000, flats: 240
# {'diff_prc_regr': 6, 'diff_prc_tree': 2, 'diff_prc_forest': 2}
# ____________________________________________________________
# bielany, max price: 459000.0, flats: 73
# {'diff_prc_regr': 15, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# bielany, max price: 472000.0, flats: 122
# {'diff_prc_regr': 13, 'diff_prc_tree': 5, 'diff_prc_forest': 5}
# ____________________________________________________________
# bielany, max price: 525000.0, flats: 237
# {'diff_prc_regr': 13, 'diff_prc_tree': 5, 'diff_prc_forest': 5}
# ____________________________________________________________
# bielany, max price: 889999, flats: 328
# {'diff_prc_regr': 13, 'diff_prc_tree': 5, 'diff_prc_forest': 5}
# ____________________________________________________________
# wlochy, max price: 390624.75, flats: 13
# {'diff_prc_regr': 34, 'diff_prc_tree': 28, 'diff_prc_forest': 29}
# ____________________________________________________________
# wlochy, max price: 507500.0, flats: 25
# {'diff_prc_regr': 26, 'diff_prc_tree': 20, 'diff_prc_forest': 21}
# ____________________________________________________________
# wlochy, max price: 603250.0, flats: 37
# {'diff_prc_regr': 22, 'diff_prc_tree': 15, 'diff_prc_forest': 16}
# ____________________________________________________________
# wlochy, max price: 859750, flats: 49
# {'diff_prc_regr': 19, 'diff_prc_tree': 16, 'diff_prc_forest': 15}
# ____________________________________________________________
# usrus, max price: 439000.0, flats: 23
# {'diff_prc_regr': 23, 'diff_prc_tree': 16, 'diff_prc_forest': 14}
# ____________________________________________________________
# usrus, max price: 492000.0, flats: 51
# {'diff_prc_regr': 15, 'diff_prc_tree': 14, 'diff_prc_forest': 12}
# ____________________________________________________________
# usrus, max price: 684500.0, flats: 76
# {'diff_prc_regr': 14, 'diff_prc_tree': 12, 'diff_prc_forest': 11}
# ____________________________________________________________
# usrus, max price: 950000, flats: 101
# {'diff_prc_regr': 15, 'diff_prc_tree': 11, 'diff_prc_forest': 9}
# ____________________________________________________________
# rembertow, max price: 480000.0, flats: 13
# {'diff_prc_regr': 32, 'diff_prc_tree': 25, 'diff_prc_forest': 20}
# ____________________________________________________________
# rembertow, max price: 480000.0, flats: 13
# {'diff_prc_regr': 32, 'diff_prc_tree': 25, 'diff_prc_forest': 20}
# ____________________________________________________________
# rembertow, max price: 560000.0, flats: 37
# {'diff_prc_regr': 23, 'diff_prc_tree': 10, 'diff_prc_forest': 9}
# ____________________________________________________________
# rembertow, max price: 599000, flats: 54
# {'diff_prc_regr': 17, 'diff_prc_tree': 7, 'diff_prc_forest': 6}
# ____________________________________________________________
