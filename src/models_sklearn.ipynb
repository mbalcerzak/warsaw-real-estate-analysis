# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
data = pd.read_pickle("../data_preprocessed/data.pkl")

# %%
data['date'] = pd.to_numeric(pd.to_datetime(data['date']))
# TODO separate days, months as features (more expensive in some months??)

cols_cat = [
 'district',
 'parking']

for c in cols_cat:
    if c in data:
        data[c] = pd.Categorical(data[c])

data.head(3)
# Out:
#     price_id  flat_id   price                 date  flat_id  \
# 4          5        4  390000  1610928000000000000        4
# 11        12       11  500000  1611705600000000000       11
# 12        13       12  590000  1611878400000000000       12
#
#                         ad_id  \
# 4   1004683230600910484697409
# 11  1005929025950911462330809
# 12  1005939166310911450918709
#
#                                                 title date_posted  \
# 4      Nowa kawalerka do wprowadzenia w chmurach 15p   2019-04-04
# 11  Za gotówkę ! Praga Południe gratka dla inwesto...  2019-09-22
# 12  50m, Praga Południe (będzie Metro), 2 pokoje d...  2019-09-23
#
#    date_scraped                  location  ... num_bathrooms flat_area   text  \
# 4    2021-01-18  Praga Południe, Warszawa  ...             1        26  Garaż
# 11   2021-01-27  Praga Południe, Warszawa  ...             1        43   Brak
# 12   2021-01-29  Praga Południe, Warszawa  ...             1        50   Brak
#
#                                           description  \
# 4   AGENCJE NIERUCHOMOSCI PROSZĘ NIE DZWONIĆ! BEZP...
# 11  Mieszkanie dobrze rozplanowane 2 pokoje z osob...
# 12  Zakup tylko za gotówkę - grunt podlega regulac...
#
#                                          photos_links  \
# 4   ['https://i.ebayimg.com/00/s/NjAwWDgwMA==/z/m4...
# 11  ['https://i.ebayimg.com/00/s/ODAwWDU5NA==/z/hn...
# 12  ['https://i.ebayimg.com/00/s/ODAwWDYwMA==/z/Sn...
#
#                                          page_address   district  \
# 4   https://www.gumtree.pl/a-mieszkania-i-domy-spr...  praga_pld
# 11  https://www.gumtree.pl/a-mieszkania-i-domy-spr...  praga_pld
# 12  https://www.gumtree.pl/a-mieszkania-i-domy-spr...  praga_pld
#
#    private_owner parking price_per_m
# 4              1  garage       15000
# 11             1    none       11627
# 12             1    none       11800
#
# [3 rows x 23 columns]

# %%
num_selector = make_column_selector(dtype_include='number')
cat_selector = make_column_selector(dtype_include='category')

# cat_transformer = OrdinalEncoder()
cat_transformer = OneHotEncoder()
# Word to vec model - embedding for each description - LSTM --> encoding for the entire sentence, embedding for the whole desc as a new feature
# Pick features: 

scaler = StandardScaler()  # I can use a different one (max scaling ... )
transformer = make_column_transformer(
    (scaler, num_selector),
    (cat_transformer, cat_selector),
)

# %%
cols = [
#  'date',
 'num_rooms',
 'num_bathrooms',
 'flat_area',
 'district',
 'private_owner',
 'parking']

# %%
y = data['price'].copy()
X = data[cols].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)
# make sure it's stratified

X_train_raw = X_train.copy()
X_test_raw = X_test.copy()

print(X_train.shape)
# Out:
# (319622, 6)

# %%
X_train = transformer.fit_transform(X_train)
X_test = transformer.transform(X_test)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (319622, 26)
# (319622,)
# (136982, 26)

# %%
X_train_baseline = transformer.fit_transform(X_train_raw[['flat_area', 'district']])
X_test_baseline = transformer.transform(X_test_raw[['flat_area', 'district']])

# %% [markdown]
# # Regression

# %%
regr = LinearRegression()

regr.fit(X_train_baseline, y_train)
y_pred_regr = regr.predict(X_test_baseline)

print(f"Score: {regr.score(X_test_baseline, y_test)}")
print(f"Regression: {mean_absolute_error(y_test, y_pred_regr)}")
# Out:
# Score: 0.7147678768034906
# Regression: 136435.62996296302

# %% [markdown]
# # Decision Tree

# %%
regr_tree = DecisionTreeRegressor()

regr_tree.fit(X_train, y_train)
y_pred_tree = regr_tree.predict(X_test)

print(f"Score: {regr_tree.score(X_test, y_test)}")
print(f"Tree: {mean_absolute_error(y_test, y_pred_tree)}")
# Out:
# Score: 0.9048254098903495
# Tree: 72924.98491280308

# %% [markdown]
# # RandomForestRegressor

# %%
regr_forest = RandomForestRegressor()
regr_forest.fit(X_train, y_train)

y_pred_forest = regr_forest.predict(X_test)

print(f"Score: {regr_forest.score(X_test, y_test)}")
print(f"Forest: {mean_absolute_error(y_test, y_pred_forest)}")

# %% [markdown]
# # SVM

# %%
# svm = SVR()
# svm.fit(X_train, y_train)

# y_pred_svm = svm.predict(X_test)

# svm.score(X_test, y_test)

# %%
# mean_absolute_error(y_test, y_pred_svm)

# %% [markdown]
# # KNN

# %%
# knn = KNeighborsRegressor()
# knn.fit(X_train, y_train)

# y_pred_knn = knn.predict(X_test)

# print(f"Score: {knn.score(X_test, y_test)}")
# print(f"KNN: {mean_absolute_error(y_test, y_pred_knn)}")

# %% [markdown]
# # Comparison

# %%
print(f"Regression: {mean_absolute_error(y_test, y_pred_regr)}")
print(f"Tree: {mean_absolute_error(y_test, y_pred_tree)}")
print(f"Forest: {mean_absolute_error(y_test, y_pred_forest)}")
# print(f"KNN: {mean_absolute_error(y_test, y_pred_knn)}")
# Out:
# Regression: 132170.3150164895
# Tree: 70984.78393634623
# Forest: 70994.06417752705

# %%
X_test_raw['y_true'] = y_test
X_test_raw['y_pred_regr'] = y_pred_regr
X_test_raw['y_pred_tree'] = y_pred_tree
X_test_raw['y_pred_forest'] = y_pred_forest
# X_test_raw['y_pred_knn'] = y_pred_knn

# X_test_raw['diff'] = abs(X_test_raw['y_true'] - X_test_raw['y_pred'])
X_test_raw['diff_prc_regr'] = abs(X_test_raw['y_true'] - X_test_raw['y_pred_regr'])/X_test_raw['y_true']*100
X_test_raw['diff_prc_tree'] = abs(X_test_raw['y_true'] - X_test_raw['y_pred_tree'])/X_test_raw['y_true']*100
X_test_raw['diff_prc_forest'] = abs(X_test_raw['y_true'] - X_test_raw['y_pred_forest'])/X_test_raw['y_true']*100
# X_test_raw['diff_prc_knn'] = abs(X_test_raw['y_true'] - X_test_raw['y_pred_knn'])/X_test_raw['y_true']*100

pd.set_option('display.float_format', lambda x: '%.3f' % x)

X_test_raw_sorted = X_test_raw.sort_values(by=['diff_prc_tree'], ascending=False)

X_test_raw_sorted.head()
# Out:
#         num_rooms  num_bathrooms  flat_area     district  private_owner  \
# 25934           2              1         41  srodmiescie              0
# 381951          2              1         40  srodmiescie              1
# 381943          2              1         40  srodmiescie              1
# 84983           3              2         90       ochota              0
# 300096          2              1         34      mokotow              1
#
#        parking  y_true  y_pred_regr  y_pred_tree  y_pred_forest  \
# 25934   garage   58000   689441.273   618419.714     620406.316
# 381951  street   57500   677203.969   609020.408     608810.004
# 381943  street   57500   677203.969   609020.408     608810.004
# 84983   garage   90000  1121091.027   920000.000     920573.680
# 300096    none   49900   492060.959   507209.302     506871.994
#
#         diff_prc_regr  diff_prc_tree  diff_prc_forest
# 25934        1088.692        966.241          969.666
# 381951       1077.746        959.166          958.800
# 381943       1077.746        959.166          958.800
# 84983        1145.657        922.222          922.860
# 300096        886.094        916.452          915.776

# %%
list(X_test_raw_sorted)
# Out:
# ['num_rooms',
#  'num_bathrooms',
#  'flat_area',
#  'district',
#  'private_owner',
#  'parking',
#  'y_true',
#  'y_pred_regr',
#  'y_pred_tree',
#  'y_pred_forest',
#  'diff_prc_regr',
#  'diff_prc_tree',
#  'diff_prc_forest']

# %%
districts = X_test_raw['district'].unique()

for district in districts:
    df_dist = X_test_raw.loc[X_test_raw['district'] == district]

    q_25 = df_dist['y_true'].quantile(0.25) 
    q_50 = df_dist['y_true'].quantile(0.5) 
    q_75 = df_dist['y_true'].quantile(0.75) 
    max_price = max(df_dist['y_true'])

    for q in [q_25, q_50, q_75, max_price]:
        df_dist_price = df_dist.loc[df_dist['y_true'] < q]
        df_dist_price = df_dist_price[['diff_prc_regr', 'diff_prc_tree','diff_prc_forest']]

        stats_unformatted = dict(df_dist_price.mean(axis=0))
        stats = {k: int(v) for k, v in stats_unformatted.items()}

        print(f"{district}, max price: {q}, flats: {len(df_dist_price)}")
        print(stats)
        print("_"*60)
# Out:
# wola, max price: 475000.0, flats: 5914
# {'diff_prc_regr': 13, 'diff_prc_tree': 13, 'diff_prc_forest': 13}
# ____________________________________________________________
# wola, max price: 599000.0, flats: 11882
# {'diff_prc_regr': 13, 'diff_prc_tree': 12, 'diff_prc_forest': 12}
# ____________________________________________________________
# wola, max price: 752379.0, flats: 17822
# {'diff_prc_regr': 14, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# wola, max price: 2224000, flats: 23778
# {'diff_prc_regr': 15, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# praga_pld, max price: 475000.0, flats: 3195
# {'diff_prc_regr': 21, 'diff_prc_tree': 11, 'diff_prc_forest': 12}
# ____________________________________________________________
# praga_pld, max price: 580000.0, flats: 6352
# {'diff_prc_regr': 18, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# praga_pld, max price: 720000.0, flats: 9568
# {'diff_prc_regr': 17, 'diff_prc_tree': 10, 'diff_prc_forest': 10}
# ____________________________________________________________
# praga_pld, max price: 1625000, flats: 12812
# {'diff_prc_regr': 18, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# mokotow, max price: 529000.0, flats: 4470
# {'diff_prc_regr': 19, 'diff_prc_tree': 10, 'diff_prc_forest': 10}
# ____________________________________________________________
# mokotow, max price: 689000.0, flats: 9062
# {'diff_prc_regr': 18, 'diff_prc_tree': 10, 'diff_prc_forest': 10}
# ____________________________________________________________
# mokotow, max price: 998500.0, flats: 13662
# {'diff_prc_regr': 16, 'diff_prc_tree': 10, 'diff_prc_forest': 10}
# ____________________________________________________________
# mokotow, max price: 7870000, flats: 18221
# {'diff_prc_regr': 16, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# srodmiescie, max price: 550000.0, flats: 5528
# {'diff_prc_regr': 40, 'diff_prc_tree': 17, 'diff_prc_forest': 17}
# ____________________________________________________________
# srodmiescie, max price: 750000.0, flats: 11141
# {'diff_prc_regr': 29, 'diff_prc_tree': 14, 'diff_prc_forest': 14}
# ____________________________________________________________
# srodmiescie, max price: 1050000.0, flats: 16800
# {'diff_prc_regr': 25, 'diff_prc_tree': 13, 'diff_prc_forest': 13}
# ____________________________________________________________
# srodmiescie, max price: 3400000, flats: 22417
# {'diff_prc_regr': 24, 'diff_prc_tree': 13, 'diff_prc_forest': 13}
# ____________________________________________________________
# wilanow, max price: 650000.0, flats: 682
# {'diff_prc_regr': 17, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# wilanow, max price: 778450.0, flats: 1431
# {'diff_prc_regr': 14, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# wilanow, max price: 1031074.0, flats: 2144
# {'diff_prc_regr': 13, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# wilanow, max price: 2225250, flats: 2860
# {'diff_prc_regr': 13, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# ochota, max price: 469000.0, flats: 1862
# {'diff_prc_regr': 12, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# ochota, max price: 635000.0, flats: 3734
# {'diff_prc_regr': 11, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# ochota, max price: 900000.0, flats: 5575
# {'diff_prc_regr': 11, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# ochota, max price: 2182500, flats: 7483
# {'diff_prc_regr': 11, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# zoliboz, max price: 551250.0, flats: 858
# {'diff_prc_regr': 18, 'diff_prc_tree': 10, 'diff_prc_forest': 10}
# ____________________________________________________________
# zoliboz, max price: 699000.0, flats: 1722
# {'diff_prc_regr': 15, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# zoliboz, max price: 900000.0, flats: 2584
# {'diff_prc_regr': 13, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# zoliboz, max price: 2300000, flats: 3481
# {'diff_prc_regr': 14, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# praga_pln, max price: 450000.0, flats: 1155
# {'diff_prc_regr': 17, 'diff_prc_tree': 11, 'diff_prc_forest': 11}
# ____________________________________________________________
# praga_pln, max price: 550000.0, flats: 2440
# {'diff_prc_regr': 18, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# praga_pln, max price: 720000.0, flats: 3696
# {'diff_prc_regr': 17, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# praga_pln, max price: 1580000, flats: 4918
# {'diff_prc_regr': 16, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# bemowo, max price: 530000.0, flats: 2051
# {'diff_prc_regr': 16, 'diff_prc_tree': 9, 'diff_prc_forest': 9}
# ____________________________________________________________
# bemowo, max price: 615000.0, flats: 4116
# {'diff_prc_regr': 16, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# bemowo, max price: 745000.0, flats: 6225
# {'diff_prc_regr': 16, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# bemowo, max price: 5500000, flats: 8338
# {'diff_prc_regr': 16, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# targowek, max price: 432000.0, flats: 1155
# {'diff_prc_regr': 16, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# targowek, max price: 490000.0, flats: 2301
# {'diff_prc_regr': 13, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# targowek, max price: 599000.0, flats: 3486
# {'diff_prc_regr': 13, 'diff_prc_tree': 6, 'diff_prc_forest': 6}
# ____________________________________________________________
# targowek, max price: 1150000, flats: 4663
# {'diff_prc_regr': 13, 'diff_prc_tree': 6, 'diff_prc_forest': 6}
# ____________________________________________________________
# ursynow, max price: 543045.0, flats: 1688
# {'diff_prc_regr': 13, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# ursynow, max price: 660000.0, flats: 3346
# {'diff_prc_regr': 13, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# ursynow, max price: 824000.0, flats: 5058
# {'diff_prc_regr': 12, 'diff_prc_tree': 8, 'diff_prc_forest': 8}
# ____________________________________________________________
# ursynow, max price: 1825000, flats: 6763
# {'diff_prc_regr': 13, 'diff_prc_tree': 8, 'diff_prc_forest': 7}
# ____________________________________________________________
# bielany, max price: 459000.0, flats: 62
# {'diff_prc_regr': 19, 'diff_prc_tree': 11, 'diff_prc_forest': 10}
# ____________________________________________________________
# bielany, max price: 472000.0, flats: 113
# {'diff_prc_regr': 15, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# bielany, max price: 515000.0, flats: 210
# {'diff_prc_regr': 13, 'diff_prc_tree': 5, 'diff_prc_forest': 5}
# ____________________________________________________________
# bielany, max price: 873000, flats: 284
# {'diff_prc_regr': 13, 'diff_prc_tree': 5, 'diff_prc_forest': 5}
# ____________________________________________________________
# bialoleka, max price: 393000.0, flats: 199
# {'diff_prc_regr': 14, 'diff_prc_tree': 7, 'diff_prc_forest': 7}
# ____________________________________________________________
# bialoleka, max price: 415000.0, flats: 457
# {'diff_prc_regr': 10, 'diff_prc_tree': 5, 'diff_prc_forest': 5}
# ____________________________________________________________
# bialoleka, max price: 460000.0, flats: 722
# {'diff_prc_regr': 13, 'diff_prc_tree': 5, 'diff_prc_forest': 5}
# ____________________________________________________________
# bialoleka, max price: 869000, flats: 982
# {'diff_prc_regr': 13, 'diff_prc_tree': 5, 'diff_prc_forest': 5}
# ____________________________________________________________
# usrus, max price: 430000.0, flats: 14
# {'diff_prc_regr': 32, 'diff_prc_tree': 15, 'diff_prc_forest': 21}
# ____________________________________________________________
# usrus, max price: 535000.0, flats: 37
# {'diff_prc_regr': 18, 'diff_prc_tree': 10, 'diff_prc_forest': 11}
# ____________________________________________________________
# usrus, max price: 689000.0, flats: 55
# {'diff_prc_regr': 15, 'diff_prc_tree': 11, 'diff_prc_forest': 10}
# ____________________________________________________________
# usrus, max price: 980000, flats: 76
# {'diff_prc_regr': 17, 'diff_prc_tree': 12, 'diff_prc_forest': 10}
# ____________________________________________________________
# wawer, max price: 339000.0, flats: 34
# {'diff_prc_regr': 6, 'diff_prc_tree': 6, 'diff_prc_forest': 5}
# ____________________________________________________________
# wawer, max price: 339000.0, flats: 34
# {'diff_prc_regr': 6, 'diff_prc_tree': 6, 'diff_prc_forest': 5}
# ____________________________________________________________
# wawer, max price: 354000.0, flats: 141
# {'diff_prc_regr': 6, 'diff_prc_tree': 2, 'diff_prc_forest': 2}
# ____________________________________________________________
# wawer, max price: 650000, flats: 194
# {'diff_prc_regr': 7, 'diff_prc_tree': 3, 'diff_prc_forest': 3}
# ____________________________________________________________
# rembertow, max price: 480000.0, flats: 7
# {'diff_prc_regr': 28, 'diff_prc_tree': 13, 'diff_prc_forest': 13}
# ____________________________________________________________
# rembertow, max price: 480000.0, flats: 7
# {'diff_prc_regr': 28, 'diff_prc_tree': 13, 'diff_prc_forest': 13}
# ____________________________________________________________
# rembertow, max price: 560000.0, flats: 32
# {'diff_prc_regr': 19, 'diff_prc_tree': 5, 'diff_prc_forest': 4}
# ____________________________________________________________
# rembertow, max price: 599000, flats: 49
# {'diff_prc_regr': 14, 'diff_prc_tree': 3, 'diff_prc_forest': 3}
# ____________________________________________________________
# wlochy, max price: 425000.0, flats: 10
# {'diff_prc_regr': 46, 'diff_prc_tree': 23, 'diff_prc_forest': 31}
# ____________________________________________________________
# wlochy, max price: 552000.0, flats: 23
# {'diff_prc_regr': 26, 'diff_prc_tree': 12, 'diff_prc_forest': 15}
# ____________________________________________________________
# wlochy, max price: 657500.0, flats: 35
# {'diff_prc_regr': 21, 'diff_prc_tree': 12, 'diff_prc_forest': 14}
# ____________________________________________________________
# wlochy, max price: 1084000, flats: 46
# {'diff_prc_regr': 19, 'diff_prc_tree': 12, 'diff_prc_forest': 13}
# ____________________________________________________________
# wesola, max price: 398750.0, flats: 8
# {'diff_prc_regr': 48, 'diff_prc_tree': 17, 'diff_prc_forest': 23}
# ____________________________________________________________
# wesola, max price: 477434.0, flats: 16
# {'diff_prc_regr': 37, 'diff_prc_tree': 15, 'diff_prc_forest': 18}
# ____________________________________________________________
# wesola, max price: 547056.0, flats: 24
# {'diff_prc_regr': 34, 'diff_prc_tree': 19, 'diff_prc_forest': 19}
# ____________________________________________________________
# wesola, max price: 625000, flats: 31
# {'diff_prc_regr': 31, 'diff_prc_tree': 16, 'diff_prc_forest': 16}
# ____________________________________________________________
